# %%
import matplotlib.pyplot as plt

# %%
from matplotlib.offsetbox import (TextArea, DrawingArea, OffsetImage, AnnotationBbox)

# %%
import matplotlib.image as mpimg

# %%
from PIL import Image

# %%
import glob

# %%
path = "ARS"
imgs = glob.glob(path + "/*.png")

for i in imgs:
    globals()[f'{i[4:-4]}'] = mpimg.imread(i)

# %%
path2 = "MAN"
imgs2 = glob.glob(path2 + "/*.png")
for i in imgs2:
    globals()[f'{i[4:-4]}'] = mpimg.imread(i)

# %%
ball = Image.open("damir-spanic-tyj4B-lpS6M-unsplash-removebg-preview-2.png").convert("RGBA")

# %%
plt.imshow(tavares)

# %%
plt.imshow(ball.crop((135, 22, 485, 370)))

# %%
bb = ball.crop((135, 22, 485, 370)); bb
# Out:
# <PIL.Image.Image image mode=RGBA size=350x348 at 0x10993C7F0>

# %%
from matplotlib.offsetbox import OffsetImage, AnnotationBbox

# %%
bb.rotate(50, Image.BICUBIC)
# Out:
# <PIL.Image.Image image mode=RGBA size=350x348 at 0x1544621F0>

# %%
148/359
# Out:
# 0.41225626740947074

# %%
zoom = 0.035
ars_line = 4
ars_colour = "red"
man_line = 4
man_colour = "navy"
behind = "<-"
towards = "->"
lab_offset = 2.5
pad = 0

# %%
# 2:07
tavares_xy = (92,67)
saka_xy = (90,22)
nketiah_xy = (90,45)
odegaard_xy = (87,31)
cedric_xy = (74,24)

gabriel_xy = (66, 50)
smithrowe_xy = (78,67)
xhaka_xy = (79,57)
elneny_xy = (70,43)
white_xy = (61,27)
ramsdale_xy = (33,41)

degea_xy = (102,38)
sancho_xy = (82,24)
telles_xy = (92,29)
lindelof_xy = (92,42)
varane_xy = (92,35) 
matic_xy = (84,40)

mctominay_xy = (89,62)
elanga_xy = (85,58)
dalot_xy = (93,60)
fernandes_xy = (81,50)
ronaldo_xy = (65,25)

# %%
pitch = mpimg.imread("Emirates.png")

# %%
tavares_ab = AnnotationBbox( OffsetImage(tavares, zoom=zoom), xy=(85,62), xybox=tavares_xy, xycoords="data", arrowprops=dict(arrowstyle=towards, ls="dashed", lw=ars_line, color=ars_colour), frameon=False, pad=pad)
saka_ab = AnnotationBbox( OffsetImage(saka, zoom=zoom), xy=(98,21), xybox=saka_xy, xycoords="data", arrowprops=dict(arrowstyle=towards, ls="dashed", lw=5.5, color=ars_colour), frameon=False, pad=pad)
nketiah_ab = AnnotationBbox( OffsetImage(nketiah, zoom=zoom), xy=(87,51), xybox=nketiah_xy, xycoords="data", arrowprops=dict(arrowstyle=towards, ls="dashed", lw=ars_line, color=ars_colour), frameon=False, pad=pad)
odegaard_ab = AnnotationBbox( OffsetImage(odegaard, zoom=zoom), xy=(87,35), xybox=odegaard_xy, xycoords="data", arrowprops=dict(arrowstyle=towards, ls="dashed", lw=ars_line, color=ars_colour), frameon=False, pad=pad)
cedric_ab = AnnotationBbox( OffsetImage(cedric, zoom=zoom), xy=(75,28), xybox=cedric_xy, xycoords="data", arrowprops=dict(arrowstyle=towards, ls="dashed", lw=ars_line, color=ars_colour), frameon=False, pad=pad)

gabriel_ab = AnnotationBbox( OffsetImage(gabriel, zoom=zoom), xy=gabriel_xy, xybox=gabriel_xy, xycoords="data", arrowprops=dict(arrowstyle=towards, ls="dashed", lw=ars_line, color=ars_colour), frameon=False, pad=pad)
smithrowe_ab = AnnotationBbox( OffsetImage(smithrowe, zoom=zoom), xy=(74,64), xybox=smithrowe_xy, xycoords="data", arrowprops=dict(arrowstyle=towards, ls="dashed", lw=ars_line, color=ars_colour), frameon=False, pad=pad)
xhaka_ab = AnnotationBbox( OffsetImage(xhaka, zoom=zoom), xy=(98,22), xybox=xhaka_xy, xycoords="data", arrowprops=dict(arrowstyle=towards, connectionstyle="arc3,rad=-0.4", lw=6, color=ars_colour), frameon=False, pad=pad)
elneny_ab = AnnotationBbox( OffsetImage(elneny, zoom=zoom), xy=(75,44), xybox=elneny_xy, xycoords="data", arrowprops=dict(arrowstyle=towards, ls="dashed", lw=ars_line, color=ars_colour), frameon=False, pad=pad)
white_ab = AnnotationBbox( OffsetImage(white, zoom=zoom), xy=white_xy, xybox=white_xy, xycoords="data", arrowprops=dict(arrowstyle=towards, ls="dashed", lw=ars_line, color=ars_colour), frameon=False, pad=pad)
ramsdale_ab = AnnotationBbox( OffsetImage(ramsdale, zoom=zoom), xy=ramsdale_xy, xybox=ramsdale_xy, xycoords="data", arrowprops=dict(arrowstyle=towards, ls="dashed", lw=ars_line, color=ars_colour), frameon=False, pad=pad)

degea_ab = AnnotationBbox( OffsetImage(degea, zoom=zoom), xy=(105,33), xybox=degea_xy, xycoords="data", arrowprops=dict(arrowstyle=behind, ls="dashed", lw=man_line, color=man_colour), frameon=False, pad=pad)
sancho_ab = AnnotationBbox( OffsetImage(sancho, zoom=zoom), xy=(83,29), xybox=sancho_xy, xycoords="data", arrowprops=dict(arrowstyle=towards, ls="dashed", lw=man_line, color=man_colour), frameon=False, pad=pad)
telles_ab = AnnotationBbox( OffsetImage(telles, zoom=zoom), xy=(99,30), xybox=telles_xy, xycoords="data", arrowprops=dict(arrowstyle=towards, ls="dashed", lw=man_line, color=man_colour), frameon=False, pad=pad)
lindelof_ab = AnnotationBbox( OffsetImage(lindelof, zoom=zoom), xy=(94,47), xybox=lindelof_xy, xycoords="data", arrowprops=dict(arrowstyle=towards, ls="dashed", lw=man_line, color=man_colour), frameon=False, pad=pad)
varane_ab = AnnotationBbox( OffsetImage(varane, zoom=zoom), xy=(98,36), xybox=varane_xy, xycoords="data", arrowprops=dict(arrowstyle=towards, ls="dashed", lw=man_line, color=man_colour), frameon=False, pad=pad)
matic_ab = AnnotationBbox( OffsetImage(matic, zoom=zoom), xy=(86,45), xybox=matic_xy, xycoords="data", arrowprops=dict(arrowstyle=towards, ls="dashed", lw=man_line, color=man_colour), frameon=False, pad=pad)

mctominay_ab = AnnotationBbox( OffsetImage(mctominay, zoom=zoom), xy=mctominay_xy, xybox=mctominay_xy, xycoords="data", arrowprops=dict(arrowstyle=towards, ls="dashed", lw=man_line, color=man_colour), frameon=False, pad=pad)
elanga_ab = AnnotationBbox( OffsetImage(elanga, zoom=zoom), xy=(80,58), xybox=elanga_xy, xycoords="data", arrowprops=dict(arrowstyle=towards, ls="dashed", lw=man_line, color=man_colour), frameon=False, pad=pad)
dalot_ab = AnnotationBbox( OffsetImage(dalot, zoom=zoom), xy=(91,54), xybox=dalot_xy, xycoords="data", arrowprops=dict(arrowstyle=towards, ls="dashed", lw=man_line, color=man_colour), frameon=False, pad=pad)
fernandes_ab = AnnotationBbox( OffsetImage(fernandes, zoom=zoom), xy=(79,54), xybox=fernandes_xy, xycoords="data", arrowprops=dict(arrowstyle=towards, ls="dashed", lw=man_line, color=man_colour), frameon=False, pad=pad)
ronaldo_ab = AnnotationBbox( OffsetImage(ronaldo, zoom=zoom), xy=ronaldo_xy, xybox=ronaldo_xy, xycoords="data", arrowprops=dict(arrowstyle=towards, ls="dashed", lw=man_line, color=man_colour), frameon=False, pad=pad)

fig, ax = plt.subplots(figsize=(30,20))
ax.imshow(pitch, extent=[0,105,0,68])

ax.add_artist(tavares_ab)
ax.add_artist(saka_ab)
ax.add_artist(nketiah_ab)
ax.add_artist(odegaard_ab)
ax.add_artist(cedric_ab)
ax.add_artist(gabriel_ab)
ax.add_artist(smithrowe_ab)
ax.add_artist(xhaka_ab)
ax.add_artist(elneny_ab)
ax.add_artist(white_ab)
ax.add_artist(ramsdale_ab)
ax.add_artist(degea_ab)
ax.add_artist(sancho_ab)
ax.add_artist(telles_ab)
ax.add_artist(lindelof_ab)
ax.add_artist(varane_ab)
ax.add_artist(matic_ab)
ax.add_artist(mctominay_ab)
ax.add_artist(elanga_ab)
ax.add_artist(dalot_ab)
ax.add_artist(fernandes_ab)
ax.add_artist(ronaldo_ab)

#plt.savefig("JLartwork_test.png")                    
plt.show()

# %%
import random

# %%
for index, row in ronaldo.iterrows():
    print(int(row["start_x"]), int(row["start_y"]))
# Out:
# 55 31
# 62 24
# 65 31
# 65 31
# 46 46
# 73 27
# 73 27
# 58 62
# 49 32
# 18 52
# 12 48
# 20 18
# 48 32
# 10 16
# 11 17
# 6 36
# 56 20
# 10 48
# 10 46
# 75 11
# 56 11
# 46 11
# 65 41
# 58 6
# 55 66
# 96 30
# 81 22
# 97 23
# 66 34
# 67 14
# 68 15
# 74 36
# 46 68
# 47 9
# 48 65
# 77 65
# 94 66

# %%
fig, ax = plt.subplots(figsize=(52.5,34))

plt.axis([0,105,0,68]) ###

for index, row in ronaldo.iterrows():
    offset = OffsetImage(bb.rotate( random.randint(0,359), Image.BICUBIC), zoom=0.15)
    ax.add_artist(AnnotationBbox(offset, (row["start_x"], row["start_y"]), frameon=False))
    
#ax.add_artist(AnnotationBbox(offset, (80,50), frameon=False))
ax.imshow(pitch, extent=[0,105,0,68]);

# %%
fig, ax = plt.subplots(figsize=(52.5,34))

plt.axis([0,105,0,68]) ###

for i in container:
    offset = OffsetImage(bb.rotate( random.randint(0,359), Image.BICUBIC), zoom=0.25)
    ax.add_artist(AnnotationBbox(offset, i, frameon=False))
  
# for index, row in ronaldo.iterrows():
#     offset = OffsetImage(bb.rotate( random.randint(0,359), Image.BICUBIC), zoom=0.15)
#     ax.add_artist(AnnotationBbox(offset, (row["start_x"], row["start_y"]), frameon=False))
    
#ax.add_artist(AnnotationBbox(offset, (80,50), frameon=False))
ax.imshow(pitch, extent=[0,105,0,68])
plt.savefig("ronaldo_touches.png");

# %%
fig, ax = plt.subplots(figsize=(52.5,34))

plt.axis([0,105,0,68]) ###

for i in container:
    offset = OffsetImage(bb.rotate( random.randint(0,359), Image.BICUBIC), zoom=0.325fig, ax = plt.subplots(figsize=(52.5,34))

plt.axis([0,105,0,68]) ###

for i in container:
    offset = OffsetImage(bb.rotate( random.randint(0,359), Image.BICUBIC), zoom=0.25)
    ax.add_artist(AnnotationBbox(offset, i, frameon=False))
  
# for index, row in ronaldo.iterrows():
#     offset = OffsetImage(bb.rotate( random.randint(0,359), Image.BICUBIC), zoom=0.15)
#     ax.add_artist(AnnotationBbox(offset, (row["start_x"], row["start_y"]), frameon=False))
    
#ax.add_artist(AnnotationBbox(offset, (80,50), frameon=False))
ax.imshow(pitch, extent=[0,105,0,68])
plt.savefig("ronaldo_touches.png");)
    ax.add_artist(AnnotationBbox(offset, i, frameon=False))
  
# for index, row in ronaldo.iterrows():
#     offset = OffsetImage(bb.rotate( random.randint(0,359), Image.BICUBIC), zoom=0.15)
#     ax.add_artist(AnnotationBbox(offset, (row["start_x"], row["start_y"]), frameon=False))
    
#ax.add_artist(AnnotationBbox(offset, (80,50), frameon=False))
ax.imshow(pitch, extent=[0,105,0,68])
plt.tight_layout()
plt.savefig("ronaldo_touches2.png");

# %%
import pandas as pd

# %%
raw_df = pd.read_csv("../EP22_prep/touches.csv")

# %%
touches = raw_df.copy()

# %%
touches.head()
# Out:
#    start_m  start_s  end_m  end_s  half       from       to  type  \
# 0        0        0    0.0    0.0     1  fernandes      NaN   set
# 1        0        0    0.0    1.0     1  fernandes  ronaldo  pass
# 2        0        1    0.0    2.0     1    ronaldo    matic  pass
# 3        0        2    0.0    3.0     1      matic    dalot  pass
# 4        0        5    NaN    NaN     1    gabriel      NaN   won
#
#                 subtype nearest_pressure  start_x  start_y  end_x  end_y  \
# 0               kickoff              NaN     52.5     34.0    NaN    NaN
# 1                     b              NaN     52.5     34.0   55.8   31.3
# 2             backwards         odegaard     55.8     31.3   65.6   33.4
# 3             backwards          nketiah     65.6     33.4   72.2   55.2
# 4  intercepted.longball              NaN     29.7     43.0    NaN    NaN
#
#    press_x  press_y
# 0      NaN      NaN
# 1      NaN      NaN
# 2     55.7     30.4
# 3     63.4     36.4
# 4      NaN      NaN

# %%
ronaldo= touches[touches["from"] == "ronaldo"].copy()

# %%
ronaldo.head()
# Out:
#      start_m  start_s  end_m  end_s  half     from         to  type  \
# 2          0        1    0.0    2.0     1  ronaldo      matic  pass
# 23         0        1    1.0    1.0     1  ronaldo   lindelof  pass
# 106        5       24    NaN    NaN     1  ronaldo        NaN   won
# 107        5       24    5.0   25.0     1  ronaldo  fernandes  pass
# 109        5       30    NaN    NaN     1  ronaldo     elanga  pass
#
#         subtype nearest_pressure  start_x  start_y  end_x  end_y  press_x  \
# 2     backwards         odegaard     55.8     31.3   65.6   33.4     55.7
# 23    backwards              NaN     62.1     24.4   78.4   40.8      NaN
# 106  loose.ball            white     65.6     31.9    NaN    NaN     65.0
# 107   backwards            white     65.6     31.9   73.5   27.1     65.0
# 109     forward          gabriel     46.5     46.9   37.5   47.0      NaN
#
#      press_y
# 2       30.4
# 23       NaN
# 106     31.9
# 107     31.9
# 109      NaN

# %%
ronaldo.shape
# Out:
# (37, 16)

# %%
# df.loc[ (df["ethnicity"] == "Indigenous") | (df["region"] == "central"), "blood_type" ]

# %%
touches.loc[ (touches["from"] == "ronaldo") | (touches["to"] == "ronaldo"), ["half", "from", "to", "start_x", "start_y", "end_x", "end_y"]]
# Out:
#       half       from        to  start_x  start_y  end_x  end_y
# 1        1  fernandes   ronaldo     52.5     34.0   55.8   31.3
# 2        1    ronaldo     matic     55.8     31.3   65.6   33.4
# 22       1      matic   ronaldo     73.6     14.9   62.1   24.4
# 23       1    ronaldo  lindelof     62.1     24.4   78.4   40.8
# 106      1    ronaldo       NaN     65.6     31.9    NaN    NaN
# ...    ...        ...       ...      ...      ...    ...    ...
# 1304     2  mctominay   ronaldo     40.2     47.9   48.2   65.7
# 1305     2    ronaldo       NaN     48.2     65.7   77.5   65.7
# 1306     2    ronaldo    telles     77.5     65.7   89.4   66.1
# 1308     2     telles   ronaldo     98.2     66.3   94.0   66.1
# 1309     2    ronaldo       NaN     94.0     66.1  100.4   60.3
#
# [69 rows x 7 columns]

# %%
container = []
for index, row in touches.iterrows():
    if row["half"] == 2:
        if row["from"] == "ronaldo":
            container.append([ row["start_x"], row["start_y"]])
        elif row["to"] == "ronaldo":
            container.append([ row["end_x"], row["end_y"]])
    elif row["half"] == 1:
        if row["from"] == "ronaldo":
            container.append( [ 105-row["start_x"], 68-row["start_y"]])
        elif row["to"] == "ronaldo":
            container.append( [ 105-row["end_x"], 68-row["end_y"]])

# %%
container[:10]
# Out:
# [[55.8, 31.3],
#  [55.8, 31.3],
#  [62.1, 24.4],
#  [62.1, 24.4],
#  [65.6, 31.9],
#  [65.6, 31.9],
#  [46.5, 46.9],
#  [46.5, 46.9],
#  [48.8, 15.1],
#  [73.0, 27.0]]

# %%
ronaldo = touches.loc[ (touches["from"] == "ronaldo") | (touches["to"] == "ronaldo"), ["half", "from", "to", "start_x", "start_y", "end_x", "end_y"]].copy()

# %%
ronaldo["X"] = ronaldo.apply(lambda row: row["start_x"] if row["from"] == "ronaldo")
# Out:
#   File "/var/folders/d0/zf8g3jwx1r38bb54k6n7g8wr0000gn/T/ipykernel_74121/443237083.py", line 1
#     ronaldo["X"] = ronaldo.apply(lambda row: row["start_x"] if row["from"] == "ronaldo")
#                                                                                        ^
# SyntaxError: invalid syntax

# %%
ronaldo1= ronaldo[ronaldo["half"]==1].copy()

# %%
ronaldo2=ronaldo[ronaldo["half"]==2].copy()

# %%
ronaldo1
